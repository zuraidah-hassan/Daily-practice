# %%
# import dataset
# run the method we learnt value count,unique, on species column
# create a new df (iris_without_species),without the species column

# %%
import pandas as pd

df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df['species'].value_counts())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print(df['species'].unique())
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
iris_without_species = df.drop("species", axis=1)

print(iris_without_species)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
species = df["species"]

species.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
species1 = df.drop(["sepal_length","sepal_width","petal_length","petal_width"], axis=1)

species1.head()

type(species1)
# Out:
# pandas.core.frame.DataFrame

# %%
# instead
 
species2 = df.drop(["sepal_length","sepal_width","petal_length","petal_width"], axis=1)

species2.head()

type(species2)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  \
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
#    (sepal_length, sepal_width)  sepal_area  petal_area
# 0                        17.85       17.85        0.28
# 1                        14.70       14.70        0.28
# 2                        15.04       15.04        0.26
# 3                        14.26       14.26        0.30
# 4                        18.00       18.00        0.28

# %%
# calculated column sepal area
sepalarea = iris_without_species["sepal_length"] 

sepalarea.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
iris_without_species['sepal_area'] = sepalarea

iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  \
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
#    (sepal_length, sepal_width)  sepal_area  petal_area
# 0                        17.85         5.1        0.28
# 1                        14.70         4.9        0.28
# 2                        15.04         4.7        0.26
# 3                        14.26         4.6        0.30
# 4                        18.00         5.0        0.28

# %%
#petal area!!!

petalarea = iris_without_species["petal_length"] * iris_without_species["petal_width"]

iris_without_species['petal_area'] = petalarea

iris_without_species.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  \
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
#    (sepal_length, sepal_width)  sepal_area  petal_area
# 0                        17.85         5.1        0.28
# 1                        14.70         4.9        0.28
# 2                        15.04         4.7        0.26
# 3                        14.26         4.6        0.30
# 4                        18.00         5.0        0.28

# %%
# filter our parts of dataframe using pandas > 14

iris_without_species["petal_area"] = petalarea

iris_without_species.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  \
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 10           5.4          3.7           1.5          0.2
# 11           4.8          3.4           1.6          0.2
# 12           4.8          3.0           1.4          0.1
# 13           4.3          3.0           1.1          0.1
# 14           5.8          4.0           1.2          0.2
# ...

# %%
# filter our parts of dataframe using pandas 

largeFlowers = iris_without_species[iris_without_species["petal_area"] > 15]

largeFlowers.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # filter our parts of dataframe using pandas
# ----> 3 largeFlowers = iris_without_species[iris_without_species["petal_area"] > 15]
#       5 largeFlowers.head(10)
#
# NameError: name 'iris_without_species' is not defined

# %%
# filter our parts of dataframe using pandas 

largeFlowers = iris_without_species[iris_without_species["petal_area"] > 15]

largeFlowers.head(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 109           7.2          3.6           6.1          2.5
# 118           7.7          2.6           6.9          2.3
#
#      (sepal_length, sepal_width)  sepal_area  petal_area
# 109                        25.92         7.2       15.25
# 118                        20.02         7.7       15.87

# %%
# how many large flowers we have in iris dataset\
# how many flowers have sepal area exactly 16

large_flowers_count = df[df['sepal_length'] > 5].shape[0]

print("Number of large flowers (sepal_length > 5):", large_flowers_count)
# Out:
# Number of large flowers (sepal_length > 5): 118

# %%
df['sepal_area'] = df['sepal_length'] * df['sepal_width']

exact_area_count = df[df['sepal_area'] == 16].shape[0]

print("Number of flowers with sepal area exactly 16:", exact_area_count)
# Out:
# Number of flowers with sepal area exactly 16: 1

# %%
sortedLargeFlowers = largeFlowers.sort_values("sepal_area")

largeFlower = sortedLargeFlowers["sepal_area"]

largestFlower = largeFlower.max()
