# %% [markdown]
# What is Python?
#
# Python is a programming language that is:
#
# * Easy to read and write
# * Popular for Data Analysis, AI, Machine Learning, Web, Automation
# *Very suitable for beginners

# %% [markdown]
# Why use Python?
#
# ✅ Simple, English-like syntax
#
# ✅ Many free libraries
#
# ✅ Used by big companies (Google, Netflix, NASA)
#
# ✅ Great for IT, Data, and AI careers

# %% [markdown]
# What is Python used for?
#
# 📊 Data Analysis (pandas, numpy)
#
# 🤖 Machine Learning & AI
#
# 🌐 Web development
#
# ⚙ Automation / scripting
#
# 🔐 Cybersecurity tools

# %% [markdown]
# ✔ Check Python installation

# %%
# Step 1: Print (Output) 
print("Hello Python")

# %%
# Step 2: Variables

name = "Ida"
age = 30

print(name)
print(age)

# %%
# Step 3: Data Type

print(type(name))
print(type(age))

# %% [markdown]
# ### Jenis Data (Data Types)
#
# Jenis asas:
#
# * int → nombor
#
# * float → perpuluhan
#
# * str → teks
#
# * bool → True / False

# %%
print(type(name))      # str
print(type(age))       # int
print(type(height))    # float
print(type(is_working))# bool

# %%
# Step 4: Number & Calculation

a = 12
b = 13

result = a + b
print(result)

# %%
# Step 5: String vs Number

x = "12"
y = "13"

print(x + y)   # gabung string

# %%
# Step 6: Type Conversion

x = int(x)
y = int(y)

print(x + y)   # tambah nombor

# %%
# Step 7: f-string (Cara Betul Print)

print(f"{x} + {y} = {x + y}")

# %%
# Step 8: Boolean

is_active = True
print(is_active)
print(type(is_active))

# %%
# Step 9: Comparison

print(10 > 5)
print(10 == 5)
print(10 != 5)

# %%
# Step 10: If Statement

score = 70

if score >= 60:
    print("Pass")
else:
    print("Fail")

# %%
# Step 11: For Loop

for i in range(3):
    print(i)

# %%
# Step 12: While Loop

count = 0

while count < 3:
    print(count)
    count += 1

# %%
# Step 13: Multiple Assignment

a, b, c = 1, 2, 3
print(a, b, c)

# %%
# Step 14: Update Variable

x = 10
x = x + 5
print(x)

# %%
# Step 15: Comments # This is a comment

# Ini komen - Python tak baca
print("Python ignores comments")

# %%
# Step 16: Indentation ( JARAK)

if True:
    print("Ini betul")

# Ini akan error kalau tak indent

# %%
# Step 17: Simple Logic Flow

age = 18

if age >= 18:
    print("Adult")
else:
    print("Minor")

# %%
# Step 18: Basic Error Example

 #print(agee)    Uncomment untuk tengok error

# %%
# Step 19: Readable Code (Good Practice)

total_price = 50
tax = 5
final_price = total_price + tax

print(final_price)   # Nama variable mesti jelas

# %%
# Step 20: Mini Practice (DAY 1 FINAL)

num1 = 20
num2 = 5

print(f"Add: {num1 + num2}")
print(f"Subtract: {num1 - num2}")
print(f"Multiply: {num1 * num2}")
print(f"Divide: {num1 / num2}")

# %%
# DAY 1 – 10 Code Tambahan (Extra Practice)
# Code 1: Print Banyak Item

print("Python", "is", "easy")

# %%
# Code 2: String Concatenation

first = "Hello"
second = "World"

print(first + " " + second)

# %%
# Code 3: String Length

text = "Pythonnnn"
print(len(text))

# %%
# Code 4: Access Character

word = "Python"
print(word[0])
print(word[-1])

# %%
# Code 5: Simple Math Order

result = 10 + 5 * 2
print(result)

# %%
# Code 6: Round Number

value = 3.4567
print(round(value, 2))

# %%
# Code 7: Boolean from Comparison

x = 8
y = 10

is_greater = x > y
print(is_greater)

# %%
# Code 8: If with Boolean Variable

is_raining = True

if is_raining:
    print("Bring umbrella")
else:
    print("No umbrella needed")

# %%
# Code 9: For Loop with Text

for i in range(3):
    print("Learning Python")

# %%
# Code 10: Simple Counter Logic

total = 0

for i in range(1, 6):
    total += i

print(total)
