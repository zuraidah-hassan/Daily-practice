# %%
data = [
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1002, "Customer Name": "Bob Jones", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-16", "Delivery Status": True},
    {"Transaction ID": 1003, "Customer Name": "Charlie Johnson", "Email": "charlie#example.com", "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "16/09/2024", "Delivery Status": True},
    {"Transaction ID": 1004, "Customer Name": "David Lee", "Email": "david.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-17", "Delivery Status": False},
    {"Transaction ID": 1005, "Customer Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3, "Price": None, "Purchase Date": "17th Sep 2024", "Delivery Status": True},
    {"Transaction ID": 1006, "Customer Name": "Frank Wright", "Email": None, "Product": "Tablet", "Quantity": None, "Price": 600.00, "Purchase Date": "2024-09-18", "Delivery Status": False},
    {"Transaction ID": 1007, "Customer Name": "Grace Lee", "Email": "grace.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-19", "Delivery Status": True},
    {"Transaction ID": 1008, "Customer Name": "Hank Brown", "Email": "hank.brown@example.com", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/19/2024", "Delivery Status": True},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1010, "Customer Name": "Jack Davis", "Email": "jack@example.com", "Product": "Mouse", "Quantity": 5, "Price": 50.00, "Purchase Date": "2024-09-21", "Delivery Status": True},
    {"Transaction ID": 1011, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1012, "Customer Name": "Kurt Evans", "Email": "kurt.evans@example.com", "Product": "Smartwatch", "Quantity": -1, "Price": 200.00, "Purchase Date": "2024-09-22", "Delivery Status": True},
    {"Transaction ID": 1013, "Customer Name": "Liam Adams", "Email": "liam.adams@example.com", "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-23", "Delivery Status": False},
    {"Transaction ID": 1014, "Customer Name": "Mia Clark", "Email": "mia.clark@example.com", "Product": None, "Quantity": 1, "Price": 0, "Purchase Date": "2024-09-24", "Delivery Status": True},
    {"Transaction ID": 1015, "Customer Name": "Nina Turner", "Email": None, "Product": "Tablet", "Quantity": 1, "Price": 600.00, "Purchase Date": "24-09-2024", "Delivery Status": True},
    {"Transaction ID": 1016, "Customer Name": "Oscar Harris", "Email": "oscar.harris@example.com", "Product": "Laptop", "Quantity": 2, "Price": 1200.00, "Purchase Date": "2024-09-25", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": "paulyoung", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1018, "Customer Name": "Quinn Lopez", "Email": None, "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "2024-09-26", "Delivery Status": False},
    {"Transaction ID": 1019, "Customer Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024-09-27", "Delivery Status": True},
    {"Transaction ID": 1020, "Customer Name": "Steve King", "Email": "steve.king@example.com", "Product": "Mouse", "Quantity": None, "Price": 50.00, "Purchase Date": "2024-09-28", "Delivery Status": True},
]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.DataFrame(data)
df.head()
# Out:
#    Transaction ID    Customer Name                     Email     Product  \
# 0            1001      Alice Smith         alice@example.com      Laptop
# 1            1002        Bob Jones                      None  Headphones
# 2            1003  Charlie Johnson       charlie#example.com  Smartphone
# 3            1004        David Lee     david.lee@example.com      Laptop
# 4            1005     Eve Martinez  eve.martinez@example.com  Smartwatch
#
#    Quantity   Price  Purchase Date  Delivery Status
# 0       1.0  1200.0     2024-09-15             True
# 1       2.0   150.0     2024-09-16             True
# 2       1.0   800.0     16/09/2024             True
# 3       1.0  1200.0     2024-09-17            False
# 4       3.0     NaN  17th Sep 2024             True

# %%
# try to know our data better
# issues with data
# missing values

# %% [markdown]
# #### Missing Values
# - Nan

# %%
x = pd.DataFrame(learners)
x['state'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x = pd.DataFrame(learners)
#       2 x['state'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']
#
# NameError: name 'learners' is not defined

# %%
import pandas as pd

learners = { 
    'names' : ['idrees','ibrahim','hazira','mel','aisyah','amin']
}

x = pd.DataFrame(learners)

# create a new column
x['state'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']
x['state2'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']
x['state3'] = ['J & K','Selangor','N9','Johor','Selangor','Penang']

x
# Out:
#      names     state    state2    state3
# 0   idrees     J & K     J & K     J & K
# 1  ibrahim  Selangor  Selangor  Selangor
# 2   hazira        N9        N9        N9
# 3      mel     Johor     Johor     Johor
# 4   aisyah  Selangor  Selangor  Selangor
# 5     amin    Penang    Penang    Penang

# %%
x['state'] = {'a':1,'b':1,'c':1,'d':1,'e':1,'e':2}
x
# Out:
#      names  state    state2    state3
# 0   idrees    NaN     J & K     J & K
# 1  ibrahim    NaN  Selangor  Selangor
# 2   hazira    NaN        N9        N9
# 3      mel    NaN     Johor     Johor
# 4   aisyah    NaN  Selangor  Selangor
# 5     amin    NaN    Penang    Penang

# %%
x['state'] = {0:8,1:1, 2:1, 3:1, 4:9, 4: np.nan, 5: None }
# x['state'] = (1,2,3,44,55,66)

x1 = x['state'][5]

type(x1)

id(x)
# Out:
# 2412289982784

# %%
- when there is no Value
-

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   20 non-null     int64
#  1   Customer Name    20 non-null     object
#  2   Email            15 non-null     object
#  3   Product          19 non-null     object
#  4   Quantity         18 non-null     float64
#  5   Price            19 non-null     float64
#  6   Purchase Date    20 non-null     object
#  7   Delivery Status  20 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
df.describe(include='all') #numerical # values for all column
# Out:
#         Transaction ID Customer Name              Email Product   Quantity  \
# count         20.00000            20                 15      19  18.000000
# unique             NaN            19                 14       8        NaN
# top                NaN   Alice Smith  alice@example.com  Laptop        NaN
# freq               NaN             2                  2       5        NaN
# mean        1010.50000           NaN                NaN     NaN   1.611111
# std            5.91608           NaN                NaN     NaN   1.195033
# min         1001.00000           NaN                NaN     NaN  -1.000000
# 25%         1005.75000           NaN                NaN     NaN   1.000000
# 50%         1010.50000           NaN                NaN     NaN   1.500000
# 75%         1015.25000           NaN                NaN     NaN   2.000000
# max         1020.00000           NaN                NaN     NaN   5.000000
#
#               Price Purchase Date Delivery Status
# count     19.000000            20              20
# unique          NaN            19               2
# top             NaN    2024-09-15            True
# freq            NaN             2              15
# mean     536.842105           NaN             NaN
# std      472.241142           NaN             NaN
# min        0.000000           NaN             NaN
# 25%      125.000000           NaN             NaN
# 50%      300.000000           NaN             NaN
# 75%     1000.000000           NaN             NaN
# max     1200.000000           NaN             NaN

# %%
df.sample(10) #random entries info
# Out:
#     Transaction ID Customer Name                     Email     Product  \
# 11            1012    Kurt Evans    kurt.evans@example.com  Smartwatch
# 5             1006  Frank Wright                      None      Tablet
# 18            1019  Rachel Scott  rachel.scott@example.com    Keyboard
# 17            1018   Quinn Lopez                      None  Smartphone
# 3             1004     David Lee     david.lee@example.com      Laptop
# 12            1013    Liam Adams    liam.adams@example.com  Headphones
# 1             1002     Bob Jones                      None  Headphones
# 13            1014     Mia Clark     mia.clark@example.com        None
# 9             1010    Jack Davis          jack@example.com       Mouse
# 8             1009  Ivy Thompson                      None    Keyboard
#
#     Quantity   Price Purchase Date  Delivery Status
# 11      -1.0   200.0    2024-09-22             True
# 5        NaN   600.0    2024-09-18            False
# 18       2.0   100.0    2024-09-27             True
# 17       1.0   800.0    2024-09-26            False
# 3        1.0  1200.0    2024-09-17            False
# 12       2.0   150.0    2024-09-23            False
# 1        2.0   150.0    2024-09-16             True
# 13       1.0     0.0    2024-09-24             True
# 9        5.0    50.0    2024-09-21             True
# 8        2.0   100.0    2024/09/20            False

# %%
df.isnull()  #boolean method
# Out:
#     Transaction ID  Customer Name  Email  Product  Quantity  Price  \
# 0            False          False  False    False     False  False
# 1            False          False   True    False     False  False
# 2            False          False  False    False     False  False
# 3            False          False  False    False     False  False
# 4            False          False  False    False     False   True
# 5            False          False   True    False      True  False
# 6            False          False  False    False     False  False
# 7            False          False  False    False     False  False
# 8            False          False   True    False     False  False
# 9            False          False  False    False     False  False
# 10           False          False  False    False     False  False
# 11           False          False  False    False     False  False
# 12           False          False  False    False     False  False
# 13           False          False  False     True     False  False
# 14           False          False   True    False     False  False
# 15           False          False  False    False     False  False
# 16           False          False  False    False     False  False
# 17           False          False   True    False     False  False
# 18           False          False  False    False     False  False
# 19           False          False  False    False      True  False
#
#     Purchase Date  Delivery Status
# 0           False            False
# 1           False            False
# 2           False            False
# 3           False            False
# 4           False            False
# 5           False            False
# 6           False            False
# 7           False            False
# 8           False            False
# 9           False            False
# 10          False            False
# 11          False            False
# 12          False            False
# 13          False            False
# 14          False            False
# 15          False            False
# 16          False            False
# 17          False            False
# 18          False            False
# 19          False            False

# %%
countnull = df.isnull().sum()

# %% [markdown]
# # create a visualization to see which column has the highest null values

# %%
null_counts = df.isnull().sum()

plt.figure(figsize=(12,5))
plt.bar(null_counts.index, null_counts.values)
plt.xticks(rotation=45)
plt.ylabel("Number of Null Values")
plt.title("Null Values per Column")
plt.show()

# %%
df
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        2.0   150.0     2024-09-16             True
# 2        1.0   800.0     16/09/2024             True
# 3        1.0  1200.0     2024-09-17            False
# 4        3.0     NaN  17th Sep 2024             True
# 5        NaN   600.0     2024-09-18            False
# 6        1.0  1200.0     2024-09-19             True
# 7        2.0   300.0     09/19/2024             True
# 8        2.0   100.0     2024/09/20            False
# 9        5.0    50.0     2024-09-21             True
# 10       1.0  1200.0     2024-09-15             True
# 11      -1.0   200.0     2024-09-22             True
# 12       2.0   150.0     2024-09-23            False
# 13       1.0     0.0     2024-09-24             True
# 14       1.0   600.0     24-09-2024             True
# 15       2.0  1200.0     2024-09-25             True
# 16       2.0   300.0     09/25/2024             True
# 17       1.0   800.0     2024-09-26            False
# 18       2.0   100.0     2024-09-27             True
# 19       NaN    50.0     2024-09-28             True

# %%
df['Customer Name'].duplicated().sum()

df['Email'].isnull().sum()
# Out:
# np.int64(5)

# %%
countnull

# %%
df['Price'].min()

df['Price'].max()

df['Price']
# Out:
# 0     1200.0
# 1      150.0
# 2      800.0
# 3     1200.0
# 4        NaN
# 5      600.0
# 6     1200.0
# 7      300.0
# 8      100.0
# 9       50.0
# 10    1200.0
# 11     200.0
# 12     150.0
# 13       0.0
# 14     600.0
# 15    1200.0
# 16     300.0
# 17     800.0
# 18     100.0
# 19      50.0
# Name: Price, dtype: float64

# %%
data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 45, 80],  # 200 is an outlier
}

df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   45
# 4      Eve   80

# %%
plt.hist(df2['Age'])
# Out:
# (array([2., 1., 0., 1., 0., 0., 0., 0., 0., 1.]),
#  array([25. , 30.5, 36. , 41.5, 47. , 52.5, 58. , 63.5, 69. , 74.5, 80. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df2['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25cce32f4d0>,
#   <matplotlib.lines.Line2D at 0x25cce32f610>],
#  'caps': [<matplotlib.lines.Line2D at 0x25cce32f750>,
#   <matplotlib.lines.Line2D at 0x25cce32f890>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25cce32f390>],
#  'medians': [<matplotlib.lines.Line2D at 0x25cce32f9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25cce32fb10>],
#  'means': []}

# %%
dfnew = df.copy()
dfnew.head(1)
# Out:
#    Transaction ID Customer Name              Email Product  Quantity   Price  \
# 0            1001   Alice Smith  alice@example.com  Laptop       1.0  1200.0
#
#   Purchase Date  Delivery Status
# 0    2024-09-15             True

# %%
dfnew.dropna(inplace= True)

dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
df_withounull = dfnew.dropna()

dfnew.isnull().sum()

df_withounull.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew = df.copy()

# %%
dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew.dropna(subset=['Quantity','Price','Product'], inplace=True)
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity   Price Purchase Date  Delivery Status
# 0        1.0  1200.0    2024-09-15             True
# 1        2.0   150.0    2024-09-16             True
# 2        1.0   800.0    16/09/2024             True
# 3        1.0  1200.0    2024-09-17            False
# 6        1.0  1200.0    2024-09-19             True
# 7        2.0   300.0    09/19/2024             True
# 8        2.0   100.0    2024/09/20            False
# 9        5.0    50.0    2024-09-21             True
# 10       1.0  1200.0    2024-09-15             True
# 11      -1.0   200.0    2024-09-22             True
# 12       2.0   150.0    2024-09-23            False
# 14       1.0   600.0    24-09-2024             True
# 15       2.0  1200.0    2024-09-25             True
# 16       2.0   300.0    09/25/2024             True
# 17       1.0   800.0    2024-09-26            False
# 18       2.0   100.0    2024-09-27             True

# %% [markdown]
# df - outliers, missing values, duplicates
#
# don't have outliers
# missing values
# duplicates
# check for duplicates and remove duplicates
# check for missing values
# remove nan
# OR
# check and remove outliers
# impute them - filling the values

# %%
newdf = df.copy()
newdf.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
# newdf['Price'].fillna(0 , inplace=True)

# we are using a central tendency to fill the nan values

newdf = df.copy()

mean_price = newdf['Price'].median()
print(mean_price)


newdf['Price'].fillna(mean_price, inplace=True)
newdf
# Out:
# 300.0
# C:\Users\60197\AppData\Local\Temp\ipykernel_22672\3986290279.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdf['Price'].fillna(mean_price, inplace=True)
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        2.0   150.0     2024-09-16             True
# 2        1.0   800.0     16/09/2024             True
# 3        1.0  1200.0     2024-09-17            False
# 4        3.0   300.0  17th Sep 2024             True
# 5        NaN   600.0     2024-09-18            False
# 6        1.0  1200.0     2024-09-19             True
# 7        2.0   300.0     09/19/2024             True
# 8        2.0   100.0     2024/09/20            False
# 9        5.0    50.0     2024-09-21             True
# 10       1.0  1200.0     2024-09-15             True
# 11      -1.0   200.0     2024-09-22             True
# 12       2.0   150.0     2024-09-23            False
# 13       1.0     0.0     2024-09-24             True
# 14       1.0   600.0     24-09-2024             True
# 15       2.0  1200.0     2024-09-25             True
# 16       2.0   300.0     09/25/2024             True
# 17       1.0   800.0     2024-09-26            False
# 18       2.0   100.0     2024-09-27             True
# 19       NaN    50.0     2024-09-28             True

# %% [markdown]
# outliers in your data, instead of using mean, you can use median, can be a better representative of the central tendency

# %%
print(newdf['Price'].sort_values())
# Out:
# 13       0.0
# 9       50.0
# 19      50.0
# 8      100.0
# 18     100.0
# 1      150.0
# 12     150.0
# 11     200.0
# 7      300.0
# 16     300.0
# 4      300.0
# 5      600.0
# 14     600.0
# 17     800.0
# 2      800.0
# 0     1200.0
# 15    1200.0
# 10    1200.0
# 3     1200.0
# 6     1200.0
# Name: Price, dtype: float64

# %%
# column fillna() # mean median mode[0] 


squared = newdf['Quantity'] ** 2 # square everything

newQuantity = squared / (squared**0.5) # divide the squares with their roots

newQuantity

newdf['Quantity'] = newQuantity
newdf

median_qnty = newdf['Quantity'].median()

newdf['Quantity'].fillna(median_qnty, inplace=True)
newdf
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_22672\2907328083.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdf['Quantity'].fillna(median_qnty, inplace=True)
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        2.0   150.0     2024-09-16             True
# 2        1.0   800.0     16/09/2024             True
# 3        1.0  1200.0     2024-09-17            False
# 4        3.0   300.0  17th Sep 2024             True
# 5        1.5   600.0     2024-09-18            False
# 6        1.0  1200.0     2024-09-19             True
# 7        2.0   300.0     09/19/2024             True
# 8        2.0   100.0     2024/09/20            False
# 9        5.0    50.0     2024-09-21             True
# 10       1.0  1200.0     2024-09-15             True
# 11       1.0   200.0     2024-09-22             True
# 12       2.0   150.0     2024-09-23            False
# 13       1.0     0.0     2024-09-24             True
# 14       1.0   600.0     24-09-2024             True
# 15       2.0  1200.0     2024-09-25             True
# 16       2.0   300.0     09/25/2024             True
# 17       1.0   800.0     2024-09-26            False
# 18       2.0   100.0     2024-09-27             True
# 19       1.5    50.0     2024-09-28             True

# %%
newdf['Price'].quantile(0)
# Out:
# np.float64(0.0)

# %%
newdf['Price'].median()
# Out:
# np.float64(300.0)

# %%
Q1 = newdf['Price'].quantile(0.25)
Q3 = newdf['Price'].quantile(0.75)

IQR_prices = Q3 - Q1
IQR_prices
# Out:
# np.float64(762.5)

# %%
x = "a"
y = "b"
# print(f"{x:10} missing: {y}")

x = 8.44444445555
y = 5.225548588555

x1 = 5.0
print(f"{x1:04} missing: {y:5f}")
# Out:
# 05.0 missing: 5.225549

# %%
for i in countnull:

    missing = countnull.values

    total = len(df)

    bar = '|' * int(missing[i] + 1 )   # Simple visualization

    print(f"{countnull.index[i] :15} missing: {bar}")
# Out:
# Transaction ID  missing: |
# Transaction ID  missing: |
# Price           missing: ||
# Customer Name   missing: |
# Email           missing: ||||||
# Customer Name   missing: |
# Transaction ID  missing: |
# Transaction ID  missing: |

# %% [markdown]
# #### duplicate values

# %%
df.head()
# Out:
#    Transaction ID    Customer Name                     Email     Product  \
# 0            1001      Alice Smith         alice@example.com      Laptop
# 1            1002        Bob Jones                      None  Headphones
# 2            1003  Charlie Johnson       charlie#example.com  Smartphone
# 3            1004        David Lee     david.lee@example.com      Laptop
# 4            1005     Eve Martinez  eve.martinez@example.com  Smartwatch
#
#    Quantity   Price  Purchase Date  Delivery Status
# 0       1.0  1200.0     2024-09-15             True
# 1       2.0   150.0     2024-09-16             True
# 2       1.0   800.0     16/09/2024             True
# 3       1.0  1200.0     2024-09-17            False
# 4       3.0     NaN  17th Sep 2024             True

# %%
df.dropna(subset='Price' , inplace=True)

# %%
df['Price']
# Out:
# 0     1200.0
# 1      150.0
# 2      800.0
# 3     1200.0
# 4        NaN
# 5      600.0
# 6     1200.0
# 7      300.0
# 8      100.0
# 9       50.0
# 10    1200.0
# 11     200.0
# 12     150.0
# 13       0.0
# 14     600.0
# 15    1200.0
# 16     300.0
# 17     800.0
# 18     100.0
# 19      50.0
# Name: Price, dtype: float64

# %%
from scipy import stats
threshold = 3
 
z_scores = stats.zscore(df['Price'])
 
newdf_without_outliers = df[  (-threshold< z_scores) & (z_scores < threshold)  ]
 
 
newdf_without_outliers.dropna(subset='Price', inplace=True)

# %%
newdf_without_outliers
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price Purchase Date  Delivery Status
# 0        1.0  1200.0    2024-09-15             True
# 1        2.0   150.0    2024-09-16             True
# 2        1.0   800.0    16/09/2024             True
# 3        1.0  1200.0    2024-09-17            False
# 5        NaN   600.0    2024-09-18            False
# 6        1.0  1200.0    2024-09-19             True
# 7        2.0   300.0    09/19/2024             True
# 8        2.0   100.0    2024/09/20            False
# 9        5.0    50.0    2024-09-21             True
# 10       1.0  1200.0    2024-09-15             True
# 11      -1.0   200.0    2024-09-22             True
# 12       2.0   150.0    2024-09-23            False
# 13       1.0     0.0    2024-09-24             True
# 14       1.0   600.0    24-09-2024             True
# 15       2.0  1200.0    2024-09-25             True
# 16       2.0   300.0    09/25/2024             True
# 17       1.0   800.0    2024-09-26            False
# 18       2.0   100.0    2024-09-27             True
# 19       NaN    50.0    2024-09-28             True

# %%
plt.boxplot(newdf_without_outliers['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1de4fca4410>,
#   <matplotlib.lines.Line2D at 0x1de4fca4550>],
#  'caps': [<matplotlib.lines.Line2D at 0x1de4fca4690>,
#   <matplotlib.lines.Line2D at 0x1de4fca47d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1de4fc842d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1de4fca4910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1de4fca4a50>],
#  'means': []}

# %%
import pandas as pd

# %%
newdf = df.copy()

# %%
# winsorize
# price column
# what is in the price part,there is only outliers

upper = newdf['Price'].quantile(0.95)
lower = newdf['Price'].quantile(0.05)

newdf['Price_winsor'] = newdf['Price'].clip(lower, upper)

print(newdf[['Price', 'Price_winsor']].head())
# Out:
#     Price  Price_winsor
# 0  1200.0        1200.0
# 1   150.0         150.0
# 2   800.0         800.0
# 3  1200.0        1200.0
# 5   600.0         600.0

# %%
z_scores
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan])

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\60197\appdata\local\programs\python\python313\lib\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\60197\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df['Customer Name'].duplicated().sum()   #check duplicate
df['Email'].isnull().sum()              #check null
# Out:
# np.int64(5)

# %%
countnull
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
df['Price']
# Out:
# 0     1200.0
# 1      150.0
# 2      800.0
# 3     1200.0
# 4        NaN
# 5      600.0
# 6     1200.0
# 7      300.0
# 8      100.0
# 9       50.0
# 10    1200.0
# 11     200.0
# 12     150.0
# 13       0.0
# 14     600.0
# 15    1200.0
# 16     300.0
# 17     800.0
# 18     100.0
# 19      50.0
# Name: Price, dtype: float64

# %%
data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 200, 40],  # 200 is an outlier
}
 
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David  200
# 4      Eve   40

# %%
plt.boxplot(df2['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x231acd23610>,
#   <matplotlib.lines.Line2D at 0x231acd23750>],
#  'caps': [<matplotlib.lines.Line2D at 0x231acd23890>,
#   <matplotlib.lines.Line2D at 0x231acd239d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x231acd234d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x231acd23b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x231acd23c50>],
#  'means': []}

# %% [markdown]
# #### Handling Missing Value

# %%
dfnew = df.copy()
dfnew.head(1)
# Out:
#    Transaction ID Customer Name              Email Product  Quantity   Price  \
# 0            1001   Alice Smith  alice@example.com  Laptop       1.0  1200.0
#
#   Purchase Date  Delivery Status
# 0    2024-09-15             True

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   20 non-null     int64
#  1   Customer Name    20 non-null     object
#  2   Email            15 non-null     object
#  3   Product          19 non-null     object
#  4   Quantity         18 non-null     float64
#  5   Price            19 non-null     float64
#  6   Purchase Date    20 non-null     object
#  7   Delivery Status  20 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
df_withoutnull = dfnew.dropna()

dfnew.isnull().sum

df_withoutnull.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew = df.copy()

# %%
df.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew.dropna(subset =['Quantity','Price','Product'], inplace=True)
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity   Price Purchase Date  Delivery Status
# 0        1.0  1200.0    2024-09-15             True
# 1        2.0   150.0    2024-09-16             True
# 2        1.0   800.0    16/09/2024             True
# 3        1.0  1200.0    2024-09-17            False
# 6        1.0  1200.0    2024-09-19             True
# 7        2.0   300.0    09/19/2024             True
# 8        2.0   100.0    2024/09/20            False
# 9        5.0    50.0    2024-09-21             True
# 10       1.0  1200.0    2024-09-15             True
# 11      -1.0   200.0    2024-09-22             True
# 12       2.0   150.0    2024-09-23            False
# 14       1.0   600.0    24-09-2024             True
# 15       2.0  1200.0    2024-09-25             True
# 16       2.0   300.0    09/25/2024             True
# 17       1.0   800.0    2024-09-26            False
# 18       2.0   100.0    2024-09-27             True

# %% [markdown]
# # Filling these values

# %%
df
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        2.0   150.0     2024-09-16             True
# 2        1.0   800.0     16/09/2024             True
# 3        1.0  1200.0     2024-09-17            False
# 4        3.0     NaN  17th Sep 2024             True
# 5        NaN   600.0     2024-09-18            False
# 6        1.0  1200.0     2024-09-19             True
# 7        2.0   300.0     09/19/2024             True
# 8        2.0   100.0     2024/09/20            False
# 9        5.0    50.0     2024-09-21             True
# 10       1.0  1200.0     2024-09-15             True
# 11      -1.0   200.0     2024-09-22             True
# 12       2.0   150.0     2024-09-23            False
# 13       1.0     0.0     2024-09-24             True
# 14       1.0   600.0     24-09-2024             True
# 15       2.0  1200.0     2024-09-25             True
# 16       2.0   300.0     09/25/2024             True
# 17       1.0   800.0     2024-09-26            False
# 18       2.0   100.0     2024-09-27             True
# 19       NaN    50.0     2024-09-28             True

# %%
new = df.copy()

dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              4
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew['Price'].fillna(o , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 dfnew['Price'].fillna(o , inplace=True)
#
# NameError: name 'o' is not defined

# %%
newdf = df.copy()

mean_price = newdf['Price'].mean().round(2)
print(mean_price)

newdf['Price'].fillna(mean_price, inplace =True)
newdf
# Out:
# 536.84
# C:\Users\60197\AppData\Local\Temp\ipykernel_23272\3498477846.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdf['Price'].fillna(mean_price, inplace =True)
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0  1200.00     2024-09-15             True
# 1        2.0   150.00     2024-09-16             True
# 2        1.0   800.00     16/09/2024             True
# 3        1.0  1200.00     2024-09-17            False
# 4        3.0   536.84  17th Sep 2024             True
# 5        NaN   600.00     2024-09-18            False
# 6        1.0  1200.00     2024-09-19             True
# 7        2.0   300.00     09/19/2024             True
# 8        2.0   100.00     2024/09/20            False
# 9        5.0    50.00     2024-09-21             True
# 10       1.0  1200.00     2024-09-15             True
# 11      -1.0   200.00     2024-09-22             True
# 12       2.0   150.00     2024-09-23            False
# 13       1.0     0.00     2024-09-24             True
# 14       1.0   600.00     24-09-2024             True
# 15       2.0  1200.00     2024-09-25             True
# 16       2.0   300.00     09/25/2024             True
# 17       1.0   800.00     2024-09-26            False
# 18       2.0   100.00     2024-09-27             True
# 19       NaN    50.00     2024-09-28             True

# %%
newdf = df.copy()

mean_price = newdf['Quantity'].mean().round(2)
print(mean_price)

newdf['Price'].fillna(mean_price, inplace =True)
newdf
# Out:
# 1.61
# C:\Users\60197\AppData\Local\Temp\ipykernel_23272\2817639573.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdf['Price'].fillna(mean_price, inplace =True)
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0  1200.00     2024-09-15             True
# 1        2.0   150.00     2024-09-16             True
# 2        1.0   800.00     16/09/2024             True
# 3        1.0  1200.00     2024-09-17            False
# 4        3.0     1.61  17th Sep 2024             True
# 5        NaN   600.00     2024-09-18            False
# 6        1.0  1200.00     2024-09-19             True
# 7        2.0   300.00     09/19/2024             True
# 8        2.0   100.00     2024/09/20            False
# 9        5.0    50.00     2024-09-21             True
# 10       1.0  1200.00     2024-09-15             True
# 11      -1.0   200.00     2024-09-22             True
# 12       2.0   150.00     2024-09-23            False
# 13       1.0     0.00     2024-09-24             True
# 14       1.0   600.00     24-09-2024             True
# 15       2.0  1200.00     2024-09-25             True
# 16       2.0   300.00     09/25/2024             True
# 17       1.0   800.00     2024-09-26            False
# 18       2.0   100.00     2024-09-27             True
# 19       NaN    50.00     2024-09-28             True

# %%
newdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 newdf
#
# NameError: name 'newdf' is not defined
