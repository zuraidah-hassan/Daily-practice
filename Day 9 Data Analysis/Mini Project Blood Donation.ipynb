# %%
import pandas as pd

# %%
import pandas as pd
#import csv data
blooddonation = pd.read_csv(r"C:\\Users\60197\OneDrive\Desktop\Daily AIML\blooddonation.csv")

# %%
import seaborn as sns

# %%
blooddonation.shape
# Out:
# (473005, 1)

# %%
df = pd.read_csv("blooddonation.csv")
print(df.head)
print(df.tail)
# Out:
# <bound method NDFrame.head of            date\tstate\tblood_type\tdonations
# 0                    1/1/2006\tJohor\tall\t87
# 1                    1/2/2006\tJohor\tall\t15
# 2                     1/3/2006\tJohor\tall\t8
# 3                    1/4/2006\tJohor\tall\t33
# 4                    1/5/2006\tJohor\tall\t20
# ...                                       ...
# 473000  11/29/2025\tW.P. Kuala Lumpur\tab\t34
# 473001  11/30/2025\tW.P. Kuala Lumpur\tab\t45
# 473002   12/1/2025\tW.P. Kuala Lumpur\tab\t17
# 473003   12/2/2025\tW.P. Kuala Lumpur\tab\t35
# 473004   12/3/2025\tW.P. Kuala Lumpur\tab\t25
#
# [473005 rows x 1 columns]>
# <bound method NDFrame.tail of            date\tstate\tblood_type\tdonations
# 0                    1/1/2006\tJohor\tall\t87
# 1                    1/2/2006\tJohor\tall\t15
# 2                     1/3/2006\tJohor\tall\t8
# 3                    1/4/2006\tJohor\tall\t33
# 4                    1/5/2006\tJohor\tall\t20
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473005 entries, 0 to 473004
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        473005 non-null  datetime64[ns]
#  1   state       473005 non-null  object
#  2   blood_type  473005 non-null  object
#  3   donations   473005 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.4+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 4️⃣ Create the bar plot
plt.figure(figsize=(10,6))
plt.bar(donations_by_state.index, donations_by_state.values, color='red')
plt.title('Total Blood Donations by State')
plt.xlabel('State')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 4️⃣ Create line chart
plt.figure(figsize=(12,6))
plt.plot(donations_over_time.index, donations_over_time.values, color='green')
plt.title('Total Blood Donations Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 4️⃣ Create scatter plot
plt.figure(figsize=(8,6))
plt.scatter(donations_by_state.index, donations_by_state.values, color='green')
plt.title('Total Blood Donations by State')
plt.xlabel('State')
plt.ylabel('Number of Donations')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
blooddonation = pd.read_csv(r"C:\Users\60197\OneDrive\Desktop\Daily AIML\blooddonation.csv", sep='\t')

print(blooddonation.columns.tolist())
print(blooddonation.head())
# Out:
# ['date', 'state', 'blood_type', 'donations']
#        date  state blood_type  donations
# 0  1/1/2006  Johor        all         87
# 1  1/2/2006  Johor        all         15
# 2  1/3/2006  Johor        all          8
# 3  1/4/2006  Johor        all         33
# 4  1/5/2006  Johor        all         20

# %%
sns.scatterplot(data=blooddonation, x='state', y='donations', hue='blood_type')
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df_pair, hue='state', height=2.5)

# %% [markdown]
# #source - https://data.gov.my/data-catalogue/blood_donations_state
#
# 1. What is the problem?
#  * Number of blood donation decreasing,this causing shortages in hospital   and effect the  capability of emergency response and medical procedures
#
# 2.Who is solution for?
#  * Hospitals,Blood banks,Patients who need regular or emergency blood supply
#
# 3.Where is the problem Occuring?
#  * The problem is occurring across multiple states in Malaysia
#
# 4.Why is it worth solving?
#  * Solving this problem improves national healthcare readiness and this will ensures better patient outcomes and saves lives.
