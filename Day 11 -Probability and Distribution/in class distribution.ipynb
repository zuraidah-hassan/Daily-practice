# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# how many unique value do you see in all the column, and what can u infer
# what is the average bill amount
# what is the average tip amount
# just find some new insight

# %%
df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# How many unique values do you see in all the columns, and what can you infer?
df.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
# What is the average bill amount?
df['total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
# What is the average tip amount?
df['tip'].mean()
# Out:
# np.float64(2.99827868852459)

# %%
#  find some new insight # Smoker vs Non-smoker
df.groupby('smoker')['total_bill'].mean()
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_21024\2588360390.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('smoker')['total_bill'].mean()
# smoker
# Yes    20.756344
# No     19.188278
# Name: total_bill, dtype: float64

# %%
# aggregate #count average bill, average tip, max bill, min bill.
df.groupby('day').agg({
    'total_bill': ['mean', 'max', 'min'],
    'tip': ['mean', 'max', 'min']
})
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_21024\975941352.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day').agg({
#      total_bill                    tip
#            mean    max   min      mean    max   min
# day
# Thur  17.682742  43.11  7.51  2.771452   6.70  1.25
# Fri   17.151579  40.17  5.75  2.734737   4.73  1.00
# Sat   20.441379  50.81  3.07  2.993103  10.00  1.00
# Sun   21.410000  48.17  7.25  3.255132   6.50  1.01

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='time')
plt.show()

# %%
# numerical -where you have numbers, integers, floats

# categorical -in which you have classes/group of things

df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# catagorical data
df['day'].unique()
df['time'].unique()
df['size'].unique()

df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df['total_bill'].__len__()

df['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 21.01    2
# 20.69    2
# 10.33    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 2.50    10
# 5.00    10
#         ..
# 1.47     1
# 1.17     1
# 4.67     1
# 5.92     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
df['tip'].unique() # won't give you results that you can use

df['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 2.50    10
# 5.00    10
#         ..
# 1.47     1
# 1.17     1
# 4.67     1
# 5.92     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
# check, how many rich or generous people come to our restaurant
# what is the size or rich people or high class people visitng a place to buy
# max of the total bill

df['total_bill'].max()

# values for tips
df['tip'].max()

dftips = df['tip']
dftips
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 21.01    2
# 20.69    2
# 10.33    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
df['tip'].unique()

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
y = df['size'].value_counts()
y
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
#create a bar graph for size column
x = df['size']
y = df['time'].value_counts()

# %%
# create a bar graph for size column
x = df['size'].unique()
y = df['size'].value_counts()

plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
#create a bar graph for size column

sns.countplot(data=df, x='size', hue='time')  # 'hue' optional
plt.title('Frequency of Size by Time')
plt.xlabel('Size of Party')
plt.ylabel('Count')
plt.show()

# %%
seriestime =df['time'].value_counts()
seriestime
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
x = seriestime.index

# %%
sns.barplot(data=df, x='size', y = y )
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x = df['tip'].unique()
y = df['tip'].value_counts()

sns.barplot(data=df, x='tip' ,y=y )
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
# histogram

sns.histplot (df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
# Prediction - healthcare, cancer prediction -xrays
# Data

# %% [markdown]
# Distribution
#  - how the frequency of something is distributed
#  - That if you take a **sample size** of 100 people:
#  -i want to know how tall the people of Phileo are,ages between 18 to 45
#
#  7 feet
#  5 feet
#  3 feet
#
#  - selecting a sample size: 5K -> 100
#  - measuring
#  - rowa of data: 100 rows of data
#  - name, age, height, gender, ethnicity

# %% [markdown]
# ## AI ETHICS
#  - data privacy -if the data is safe with the researcher - anonimity
#  - data transparency - how are you using the data

# %%
data = {
    'name': ['idrees','hazirah','atirah','mel','nazri','ibrahim','amin'],
    'age': [29,24,31,27,20,18,27],
    'height':[185, 152, 163, 162,164,168,168],
    'gender':['m','f','f','f','m','m','m'],
    'ethnicity':['kashmiri','malay','malay','malay','malay','malay','malay']
}

# %%
import pandas as pd

df = pd.DataFrame(data)
df.head(7)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay

# %%
sns.histplot(data = df, x = 'height'  )
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df.head()
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay

# %%
df['gender'].value_counts() #Frequency Distribution
# Out:
# gender
# m    4
# f    3
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
print(df['ethnicity'].value_counts())
# Out:
# gender
# m    4
# f    3
# Name: count, dtype: int64
# ethnicity
# malay       6
# kashmiri    1
# Name: count, dtype: int64

# %%
df['height'].value_counts()
# Out:
# height
# 168    2
# 185    1
# 152    1
# 163    1
# 162    1
# 164    1
# Name: count, dtype: int64

# %%
#bar chart for height
sns.countplot(data=df, x='height')
plt.title('Frequency of Height')
plt.xlabel('Height')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot

# %%
#histogram for height
sns.histplot(data=df, x='height', bins=5, kde=True)
plt.title('Histogram of Height')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
#filtering ethnicity
malay_df = df.loc[df['ethnicity'] == 'malay']
malay_df
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay

# %%
#filtering age over 21
filtered = malay_df[malay_df['age'] > 21]
filtered
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 6     amin   27     168      m     malay

# %%
df.head(2)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay

# %%
malay =df[    df['ethnicity'] == 'malay']
print(malay)

female =df[    df['gender'] == 'f']
print(female)

malayover21 = df[    (df['ethnicity'] == 'malay') & (df['age'] > 21 ) ]
malayover21
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   31     163      f     malay
# 3      mel   27     162      f     malay
# 6     amin   27     168      m     malay

# %%
sns.histplot(data = malay, x = 'height' , kde=True )
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
import seaborn as sns

# %%
tipsdf =sns.load_dataset('tips')

tipsdf.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# create these dataframe
# 1. only male
# 2. tips above 6 dollar
# 3. smokers dining on sunday

# %%
df.columns
# Out:
# Index(['name', 'age', 'height', 'gender', 'ethnicity'], dtype='object')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 1. only male
male_df = df[df['gender'] == 'm']
male_df
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 4    nazri   20     164      m     malay
# 5  ibrahim   18     168      m     malay
# 6     amin   27     168      m     malay

# %%
# 2. tips above 6 dollar
tips_above_6 = df[df['tip'] > 6]
tips_above_6
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3

# %%
# 3. smokers dining on sunday
smokers_sunday = df[(df['smoker'] == 'Yes') & (df['day'] == 'Sun')]
smokers_sunday
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# ...

# %%
df[df['smoker'] == 'Yes']['day'].value_counts()
# Out:
# day
# Sat     42
# Sun     19
# Thur    17
# Fri     15
# Name: count, dtype: int64

# %%
smokers_sunday = df[(df['smoker'] == 'Yes') & (df['day'] == 'Sun')]
sns.countplot(data=smokers_sunday, x='sex',)  # 'sex' = Male/Female
plt.title('Smokers on Sunday by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
smoke_sunday = tipsdf[
    (tipsdf['smoker'] != 'No') &
    (tipsdf['day'] == 'Sun') &
    (tipsdf['time'] == 'Dinner')
]
smoke_sunday
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# ...

# %%
maledf = tipsdf[ tipsdf['sex'] == 'Male'  ]

tips6 = tipsdf[ tipsdf['tip'] > 6  ]

smoker_dining_sunday = tipsdf[ (tipsdf['smoker'] == 'Yes' ) & ( tipsdf['time'] == 'Dinner')  & ( tipsdf['day'] == 'Sun' )  ]
smoker_dining_sunday
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# ...

# %% [markdown]
# - Checking the distribution of data in our dataset
#
# -or how many data points, there are for male and female?
# -how many for each week?
# -how many for each ethnicity?

# %% [markdown]
# -checking if we can rely on data
# -looking at sample size to check for anything out of ordinary
#
# we study distribution in ML, because class distribution influence the outputs of AI Models
#
# -very simple example:Case study:
# -a company in US. Security.
# -they wanted to create a tool,that would screen criminal?
# -just by looking at face that somebody is a criminal?
#
# -there should be a database. there should be data
#
# -more examples of black people, in their data base along with the crimes they had committed.
# -vs the white or hispanic examples
#
# -1000 african american criminal cases
# -100 white hispanic
#
# -data to AI Model, will always be correct when labelling a african american as a criminal?
#
# it lead to false arrests
#
# **class imbalance**
#
# -if there is more data related to one class compared to other
#      - eg. Male Female = 100:
